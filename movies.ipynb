# %% [markdown]
# Markdown and $\LaTeX$ will be included using the option TemplateExporter.exclude_input.  For example, to convert movies.pynb to html and exclude the code cells `jupyter nbconvert --TemplateExporter.exclude_input=True movies.ipynb`

# %% [markdown]
# # NYT Data

# %%
import json
import requests
import pandas as pd
from pandas.io.json import json_normalize

url = 'http://api.nytimes.com/svc/movies/v2/reviews/search.json?query=big&opening-date=1930-01-01;2000-01-01&api-key=ae71411b586e4f9c82502e7e782b122d'
df = pd.read_json(url, orient = 'records')
df.head()
# Out:
#   status                                          copyright  has_more  \
# 0     OK  Copyright (c) 2018 The New York Times Company....      True
# 1     OK  Copyright (c) 2018 The New York Times Company....      True
# 2     OK  Copyright (c) 2018 The New York Times Company....      True
# 3     OK  Copyright (c) 2018 The New York Times Company....      True
# 4     OK  Copyright (c) 2018 The New York Times Company....      True
#
#    num_results                                            results
# 0           20  {'display_title': 'Deuce Bigalow: Male Gigolo'...
# 1           20  {'display_title': 'American Pie', 'mpaa_rating...
# 2           20  {'display_title': 'South Park: Bigger, Longer ...
# 3           20  {'display_title': 'Big Daddy', 'mpaa_rating': ...
# 4           20  {'display_title': 'The Last Big Thing', 'mpaa_...

# %%
from pandas.io.json import json_normalize
nytdata = json_normalize(df['results'])
nytdata.head()
# Out:
#                 byline  critics_pick         date_updated  \
# 0  Lawrence Van Gelder             0  2017-11-02 04:17:57
# 1       Stephen Holden             0  2017-11-02 04:17:57
# 2       Stephen Holden             1  2017-11-02 04:17:57
# 3         Janet Maslin             0  2017-11-02 04:17:57
# 4       STEPHEN HOLDEN             0  2017-11-02 04:17:56
#
#                         display_title                              headline  \
# 0          Deuce Bigalow: Male Gigolo  Deuce Bigalow: Male Gigolo (Movie)
# 1                        American Pie                American Pie (Movie)
# 2  South Park: Bigger, Longer & Uncut                  South Park (Movie)
# 3                           Big Daddy                   Big Daddy (Movie)
# 4                  The Last Big Thing         Last Big Thing, The (Movie)
#
#                             link.suggested_link_text link.type  \
# 0  Read the New York Times Review of Deuce Bigalo...   article
# 1     Read the New York Times Review of American Pie   article
# 2  Read the New York Times Review of South Park: ...   article
# 3        Read the New York Times Review of Big Daddy   article
# 4  Read the New York Times Review of The Last Big...   article
#
#                                             link.url mpaa_rating multimedia  \
# 0  http://www.nytimes.com/movie/review?res=9801E2...           R       None
# 1  http://www.nytimes.com/movie/review?res=980CE2...       NC-17       None
# 2  http://www.nytimes.com/movie/review?res=9D00EF...           R       None
# 3  http://www.nytimes.com/movie/review?res=9405E2...       PG-13       None
# 4  http://www.nytimes.com/movie/review?res=9C05E7...           R       None
#
#   opening_date publication_date  \
# 0   1999-12-10       1999-12-10
# 1   1999-07-09       1999-07-09
# 2   1999-06-30       1999-06-30
# 3   1999-06-25       1999-06-25
# 4   1998-09-23       1998-09-23
#
#                                        summary_short
# 0     Fish-tank cleaner turns male escort. Juvenile.
# 1  Teenagers vow to lose virginity by prom night....
# 2  The movie spinoff from the outrageous Comedy C...
# 3  Slacker tries fatherhood. Flimsy and sentimental.
# 4  Victims plot against performance artist. Satir...

# %% [markdown]
# # OMDb Data

# %%
apikey_omdb = "ab8ac07e"
title = 't=' + nytdata['display_title'][1].replace(' ', '+')
req = 'http://www.omdbapi.com/?apikey='+ apikey_omdb + '&'+ title
pd.read_json(req)
# Out:
#           Title  Year Rated     Released Runtime   Genre  \
# 0  American Pie  1999     R  09 Jul 1999  95 min  Comedy
# 1  American Pie  1999     R  09 Jul 1999  95 min  Comedy
# 2  American Pie  1999     R  09 Jul 1999  95 min  Comedy
#
#                   Director     Writer  \
# 0  Paul Weitz, Chris Weitz  Adam Herz
# 1  Paul Weitz, Chris Weitz  Adam Herz
# 2  Paul Weitz, Chris Weitz  Adam Herz
#
#                                               Actors  \
# 0  Jason Biggs, Chris Klein, Thomas Ian Nicholas,...
# 1  Jason Biggs, Chris Klein, Thomas Ian Nicholas,...
# 2  Jason Biggs, Chris Klein, Thomas Ian Nicholas,...
#
#                                                 Plot   ...    Metascore  \
# 0  Four teenage boys enter a pact to lose their v...   ...           58
# 1  Four teenage boys enter a pact to lose their v...   ...           58
# 2  Four teenage boys enter a pact to lose their v...   ...           58
#
#   imdbRating imdbVotes     imdbID   Type          DVD  BoxOffice  \
# 0          7   344,032  tt0163651  movie  21 Dec 1999        N/A
# 1          7   344,032  tt0163651  movie  21 Dec 1999        N/A
# 2          7   344,032  tt0163651  movie  21 Dec 1999        N/A
#
#            Production                                       Website Response
# 0  Universal Pictures  http://www.universalpictures.com/americanpie     True
# 1  Universal Pictures  http://www.universalpictures.com/americanpie     True
# 2  Universal Pictures  http://www.universalpictures.com/americanpie     True
#
# [3 rows x 25 columns]
